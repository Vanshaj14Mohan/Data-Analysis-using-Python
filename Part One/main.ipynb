# %% [markdown]
# ## Bikes Sales Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("E:\Data Analysis using Python\Part One\sales_data.csv")

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %% [markdown]
# # Numerical Analysis and Visualization

# %%
#Analyzing Unit_Cost column
df["Unit_Cost"].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
df["Unit_Cost"].mean()
# Out:
# 267.296365759581

# %%
df["Unit_Cost"].median()
# Out:
# 9.0

# %%
df["Unit_Cost"].plot(kind="box", vert=False, figsize=(6,6))
# Out:
# <Axes: >

# %%
df["Unit_Cost"].plot(kind="density", figsize=(8,6))
# Out:
# <Axes: ylabel='Density'>

# %%
ax = df["Unit_Cost"].plot(kind="density", figsize=(8,6))
ax.axvline(df["Unit_Cost"].mean(), color="red", linestyle="--", label="Mean")
ax.axvline(df["Unit_Cost"].median(), color="green", linestyle="--", label="Median")
ax.legend()

# %%
ax = df["Unit_Cost"].plot(kind="hist", bins=10, figsize=(8,6), alpha=0.7)
ax.set_xlabel("Number of Sales")
ax.set_ylabel("Frequency")
ax.set_title("Histogram of Unit Cost")
# Out:
# Text(0.5, 1.0, 'Histogram of Unit Cost')

# %% [markdown]
# # Categorical analysis and visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# We will anaylze age group column now
df["Age_Group"].describe()
# Out:
# count             113036
# unique                 4
# top       Adults (35-64)
# freq               55824
# Name: Age_Group, dtype: object

# %%
df["Age_Group"].value_counts()
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %%
df["Age_Group"].value_counts().plot(kind="bar", figsize=(6,5), label="Count", color="green", alpha=0.6)
plt.xlabel("Age Group")
plt.ylabel("Number of Customers")
plt.title("Number of Customers by Age Group")
plt.legend()
plt.show()

# %%
# By using a pie chart
df["Age_Group"].value_counts().plot(kind="pie", figsize=(6,6))
plt.title("Age Group Distribution")
# Out:
# Text(0.5, 1.0, 'Age Group Distribution')

# %% [markdown]
# # Relationship between the columns

# %%
#Try finding out any signinficant relationship between the columns
corr = df.corr(numeric_only=True)
corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
df.plot(kind="scatter", x="Unit_Cost", y="Unit_Price", figsize=(8,6), alpha=0.5)
plt.xlabel("Unit Cost")
plt.ylabel("Unit Price")
plt.title("Scatter Plot of Unit Cost vs Unit Price")
plt.show()

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# Now for Customer Age and Revenue
df.plot(kind="scatter", x="Customer_Age", y="Revenue", figsize=(8,6), alpha=0.5, color="orange")
plt.xlabel("Customer Age")
plt.ylabel("Revenue")
plt.title("Scatter Plot of Customer Age vs Revenue")
plt.show()

# %%
# For revenue and profit
df.plot(kind = "scatter", x="Revenue", y="Profit", figsize=(8,6), alpha=0.7, color="purple")
plt.xlabel("Revenue")
plt.ylabel("Profit")
plt.title("Scatter Plot of Revenue vs Profit")
plt.show()

# %%
ax = df[["Profit", "Age_Group"]].boxplot(by="Age_Group", figsize=(8,6))
ax.set_xlabel("Age Group")
ax.set_ylabel("Profit")
ax.set_title("Box Plot of Profit by Age Group")
plt.suptitle("")
plt.show()

# %%
# Making different box plots for different columns 
box_col = ["Year", "Customer_Age", "Unit_Cost", "Order_Quantity", "Unit_Price", "Revenue", "Profit"]
df[box_col].plot(kind="box", subplots=True, layout=(3,3), figsize=(15,10), sharex=False, sharey=False)
# Out:
# Year                 Axes(0.125,0.653529;0.227941x0.226471)
# Customer_Age      Axes(0.398529,0.653529;0.227941x0.226471)
# Unit_Cost         Axes(0.672059,0.653529;0.227941x0.226471)
# Order_Quantity       Axes(0.125,0.381765;0.227941x0.226471)
# Unit_Price        Axes(0.398529,0.381765;0.227941x0.226471)
# Revenue           Axes(0.672059,0.381765;0.227941x0.226471)
# Profit                   Axes(0.125,0.11;0.227941x0.226471)
# dtype: object

# %% [markdown]
# # Adding a new column to calculate Revenue_per_Age

# %%
#Column wrangling - Adding a new column to calculate Revenue_per_Age 
df["Revenue_per_Age"] = df["Revenue"] / df["Customer_Age"]
df["Revenue_per_Age"].head()
# Out:
# 0    50.000000
# 1    50.000000
# 2    49.000000
# 3    42.612245
# 4     8.893617
# Name: Revenue_per_Age, dtype: float64

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df["Revenue_per_Age"].describe()
# Out:
# count    113036.000000
# mean         23.009000
# std          42.256559
# min           0.023529
# 25%           1.850000
# 50%           6.563636
# 75%          24.318182
# max        1116.807692
# Name: Revenue_per_Age, dtype: float64

# %%
df["Revenue_per_Age"].plot(kind="density", figsize=(6,6))
# Out:
# <Axes: ylabel='Density'>

# %%
df["Revenue_per_Age"].plot(kind="hist", figsize=(6,6))
plt.xlabel("Revenue per Age")
plt.ylabel("Frequency")
plt.title("Histogram of Revenue per Age")
plt.show()

# %% [markdown]
# # Adding a new column named Calculated Cost

# %%
df.head(2)
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category Sub_Category  \
# 0  Canada  British Columbia      Accessories   Bike Racks
# 1  Canada  British Columbia      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
#
#    Revenue  Revenue_per_Age
# 0      950             50.0
# 1      950             50.0

# %%
# Adding a new column named Calculated Cost -> Calculated_cost = Quantity * Unit cost
df["Calculated_Cost"] = df["Order_Quantity"] * df["Unit_Cost"]
df.head(2)
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category Sub_Category  \
# 0  Canada  British Columbia      Accessories   Bike Racks
# 1  Canada  British Columbia      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
#
#    Revenue  Revenue_per_Age  Calculated_Cost
# 0      950             50.0              360
# 1      950             50.0              360

# %%
df["Calculated_Cost"].head()
# Out:
# 0     360
# 1     360
# 2    1035
# 3     900
# 4     180
# Name: Calculated_Cost, dtype: int64

# %%
(df["Calculated_Cost"] != df["Cost"]).sum()
# Out:
# 0

# %%
# Draw a relationship plot between Cost and Profit using scatter plot
df.plot(kind="scatter", x="Calculated_Cost", y="Profit", figsize=(8,6), alpha=0.7, color="red")
plt.xlabel("Calcluated Cost")
plt.ylabel("Profit")
plt.title("Scatter Plot of Calculated Cost vs Cost")
plt.show()

# %% [markdown]
# # Adding a new column named Calculated_Revenue

# %%
# Adding a new column named Calculated_Revenue
#Formula calculated_revenue = cost + profit
df["Calculated_Revenue"] = df["Calculated_Cost"] + df["Profit"]
df.head(2)
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category  ...              Product  \
# 0  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
# 1  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
#
#   Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue  \
# 0              8         45         120     590   360      950
# 1              8         45         120     590   360      950
#
#    Revenue_per_Age  Calculated_Cost  Calculated_Revenue
# 0             50.0              360                 950
# 1             50.0              360                 950
#
# [2 rows x 21 columns]

# %%
df["Calculated_Revenue"].head()
# Out:
# 0     950
# 1     950
# 2    2401
# 3    2088
# 4     418
# Name: Calculated_Revenue, dtype: int64

# %%
df["Calculated_Revenue"].plot(kind="hist", figsize=(6,6))
plt.xlabel("Calculated Revenue")
plt.ylabel("Frequency")
plt.title("Histogram of Calculated Revenue")
plt.show()

# %%
df["Revenue"].head()
# Out:
# 0     950
# 1     950
# 2    2401
# 3    2088
# 4     418
# Name: Revenue, dtype: int64

# %%
(df["Calculated_Revenue"] != df["Revenue"]).sum()
# Out:
# 0

# %%
df["Revenue"].plot(kind="hist", figsize=(8,6), bins = 20, alpha=0.8)
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.title("Histogram of Revenue")
plt.show()

# %% [markdown]
# # Modify all Unit_Price values adding 3% tax on them

# %%
df.head(2)
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category  ...              Product  \
# 0  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
# 1  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
#
#   Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue  \
# 0              8         45         120     590   360      950
# 1              8         45         120     590   360      950
#
#    Revenue_per_Age  Calculated_Cost  Calculated_Revenue
# 0             50.0              360                 950
# 1             50.0              360                 950
#
# [2 rows x 21 columns]

# %%
df["Unit_Price"].head()
# Out:
# 0    120
# 1    120
# 2    120
# 3    120
# 4    120
# Name: Unit_Price, dtype: int64

# %%
# Adding tax now
df["Unit_Price"] = df["Unit_Price"] * 1.03

# Could also do -> df["Unit_Price"] *= 1.03
df["Unit_Price"].head()
# Out:
# 0    123.6
# 1    123.6
# 2    123.6
# 3    123.6
# 4    123.6
# Name: Unit_Price, dtype: float64

# %%
df.head(2)
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category  ...              Product  \
# 0  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
# 1  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
#
#   Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue  \
# 0              8         45       123.6     590   360      950
# 1              8         45       123.6     590   360      950
#
#    Revenue_per_Age  Calculated_Cost  Calculated_Revenue
# 0             50.0              360                 950
# 1             50.0              360                 950
#
# [2 rows x 21 columns]

# %% [markdown]
# # Selection & Indexing

# %%
# Get all sales in the state of British Columbia
df["State"].to_list()
# Out:
# ['British Columbia',
#  'British Columbia',
#  'New South Wales',
#  'New South Wales',
#  'New South Wales',
#  'New South Wales',
#  'Victoria',
#  'Victoria',
#  'Victoria',
#  'Victoria',
#  'Victoria',
#  'Victoria',
#  'Victoria',
#  'Victoria',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'Oregon',
#  'Oregon',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'Oregon',
#  'Oregon',
#  'British Columbia',
#  'British Columbia',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'British Columbia',
#  'Saarland',
#  'Saarland',
# ...

# %%
df.loc[df["State"]== "British Columbia"]
# Out:
#               Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0       2013-11-26   26   November  2013            19           Youth (<25)
# 1       2015-11-26   26   November  2015            19           Youth (<25)
# 14      2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15      2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16      2013-09-02    2  September  2013            29  Young Adults (25-34)
# ...            ...  ...        ...   ...           ...                   ...
# 112885  2016-07-05    5       July  2016            38        Adults (35-64)
# 112952  2013-08-18   18     August  2013            31  Young Adults (25-34)
# 112953  2015-08-18   18     August  2015            31  Young Adults (25-34)
# 112954  2013-09-21   21  September  2013            31  Young Adults (25-34)
# 112955  2015-09-21   21  September  2015            31  Young Adults (25-34)
#
# ...

# %%
# Plotting Unit Price distribution for British Columbia
british_col = df.loc[df["State"]== "British Columbia"]
british_col["Unit_Price"].plot(kind="hist", figsize=(8,6))
plt.xlabel("Unit Price")
plt.title("Unit Price Distribution in British Columbia")
plt.show()

# %%
# Plotting Unit Price distribution for California 
california_dist = df.loc[df["State"] == "California"]
california_dist["Unit_Price"].plot(kind="hist", figsize=(8,6), color="orange")
plt.xlabel("Unit Price")
plt.ylabel("Frequency")
plt.title("Unit Price Distribution in California")
plt.show()

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category  ...  \
# 0               M     Canada  British Columbia      Accessories  ...
# 1               M     Canada  British Columbia      Accessories  ...
# 2               M  Australia   New South Wales      Accessories  ...
# 3               M  Australia   New South Wales      Accessories  ...
# 4               F  Australia   New South Wales      Accessories  ...
#
#                Product Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike              8         45       123.6     590   360
# ...

# %%
#Get mean revenue of the adults (35-64) sales group
df.loc[df["Age_Group"] == "Adults (35-64)", "Revenue"].mean()
# Out:
# 762.8287654055604

# %%
#Get mean revenue of the Young Adults (25-34) sales group
df.loc[df["Age_Group"] == "Young Adults (25-34)", "Revenue"].mean()
# Out:
# 793.0774046670462

# %%
#Get median revenue of the Young Adults (25-34) sales group, Extra part
df.loc[df["Age_Group"] == "Young Adults (25-34)", "Revenue"].median()
# Out:
# 256.0

# %%
# How many records belong to Age Group Youth (<25) or Adults (35-64)?
# df["Age_Group"].isin(["Youth (<25)", "Adults (35-64)"]).sum()

# another method
df.loc[(df["Age_Group"] == "Youth (<25)") | (df["Age_Group"] == "Adults (35-64)")].shape[0]
# Out:
# 73652

# %%
# Get mean revenue of the sales group Young Adults (25-34) in United States
df.loc[(df["Age_Group"] == "Young Adults (25-34)") & (df["Country"] == "United States"), "Revenue"].mean()
# Out:
# 788.245075421473

# %%
#Get median revenue of the sales group Young Adults (25-34) in United States, Extra part
df.loc[(df["Age_Group"] == "Young Adults (25-34)") & (df["Country"] == "United States"), "Revenue"].median()
# Out:
# 262.0
